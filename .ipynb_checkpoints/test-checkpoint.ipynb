# %%
import autograd.numpy as np

from pymanopt.manifolds import Stiefel
from pymanopt import Problem
from pymanopt.solvers import SteepestDescent
# Out:
# You can find the C code in this temporary file: /tmp/theano_compilation_error_l3n5gji3
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/theano/gof/lazylinker_c.py in <module>()
#      80                     version,
# ---> 81                     actual_version, force_compile, _need_reload))
#      82 except ImportError:
#
# ImportError: Version check of the existing lazylinker compiled file. Looking for version 0.211, but found None. Extra debug information: force_compile=False, _need_reload=True
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/theano/gof/lazylinker_c.py in <module>()
#     104                         version,
# --> 105                         actual_version, force_compile, _need_reload))
#     106         except ImportError:
#
# ImportError: Version check of the existing lazylinker compiled file. Looking for version 0.211, but found None. Extra debug information: force_compile=False, _need_reload=True
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/theano/gof/vm.py in <module>()
#     673         raise theano.gof.cmodule.MissingGXX('lazylinker will not be imported if theano.config.cxx is not set.')
# --> 674     from . import lazylinker_c
#     675
#
# ~/.local/lib/python3.6/site-packages/theano/gof/lazylinker_c.py in <module>()
#     139             cmodule.GCC_compiler.compile_str(dirname, code, location=loc,
# --> 140                                              preargs=args)
#     141             # Save version into the __init__.py file.
#
# ~/.local/lib/python3.6/site-packages/theano/gof/cmodule.py in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module, hide_symbols)
#    2395             raise Exception('Compilation failed (return status=%s): %s' %
# -> 2396                             (status, compile_stderr.replace('\n', '. ')))
#    2397         elif config.cmodule.compilation_warning and compile_stderr:
#
# Exception: Compilation failed (return status=1): /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(abstract.o): relocation R_X86_64_32S against symbol `_Py_NotImplementedStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(boolobject.o): relocation R_X86_64_32 against `.data' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(bytearrayobject.o): relocation R_X86_64_32 against symbol `_PyByteArray_empty_string' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(bytesobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(exceptions.o): relocation R_X86_64_32S against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(floatobject.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(funcobject.o): relocation R_X86_64_32S against symbol `PyCode_Type' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(iterobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(listobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(longobject.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(dictobject.o): relocation R_X86_64_32S against `.text' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(memoryobject.o): relocation R_X86_64_32 against `.rodata.str1.8' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(methodobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(moduleobject.o): relocation R_X86_64_32 against `.rodata.str1.8' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(object.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(obmalloc.o): relocation R_X86_64_32S against `.data' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(capsule.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(rangeobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(setobject.o): relocation R_X86_64_32S against `.data' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(sliceobject.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(structseq.o): relocation R_X86_64_32 against `.data' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpy ...
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-c18267cb10dc> in <module>()
#       1 import autograd.numpy as np
#       2
# ----> 3 from pymanopt.manifolds import Stiefel
#       4 from pymanopt import Problem
#       5 from pymanopt.solvers import SteepestDescent
#
# ~/.local/lib/python3.6/site-packages/pymanopt/__init__.py in <module>()
# ----> 1 from .core.problem import Problem
#       2
#       3 __all__ = ["Problem"]
#
# ~/.local/lib/python3.6/site-packages/pymanopt/core/problem.py in <module>()
#       5 from __future__ import print_function
#       6
# ----> 7 from pymanopt.tools.autodiff import (AutogradBackend, TheanoBackend,
#       8                                      TensorflowBackend)
#       9
#
# ~/.local/lib/python3.6/site-packages/pymanopt/tools/autodiff/__init__.py in <module>()
# ----> 1 from ._theano import TheanoBackend
#       2
#       3 from ._autograd import AutogradBackend
#       4
#       5 from ._tensorflow import TensorflowBackend
#
# ~/.local/lib/python3.6/site-packages/pymanopt/tools/autodiff/_theano.py in <module>()
#       6 """
#       7 try:
# ----> 8     import theano
#       9     import theano.tensor as T
#      10     from theano.gradient import disconnected_grad
#
# ~/.local/lib/python3.6/site-packages/theano/__init__.py in <module>()
#     108     object2, utils)
#     109
# --> 110 from theano.compile import (
#     111     SymbolicInput, In,
#     112     SymbolicOutput, Out,
#
# ~/.local/lib/python3.6/site-packages/theano/compile/__init__.py in <module>()
#      10 from theano.compile.function_module import *
#      11
# ---> 12 from theano.compile.mode import *
#      13
#      14 from theano.compile.io import *
#
# ~/.local/lib/python3.6/site-packages/theano/compile/mode.py in <module>()
#       9 import theano
#      10 from theano import gof
# ---> 11 import theano.gof.vm
#      12 from theano import config
#      13 from six import string_types
#
# ~/.local/lib/python3.6/site-packages/theano/gof/vm.py in <module>()
#     681 except ImportError:
#     682     pass
# --> 683 except (OSError, theano.gof.cmodule.MissingGXX) as e:
#     684     # OSError happens when g++ is not installed.  In that case, we
#     685     # already changed the default linker to something else then CVM.
#
# AttributeError: module 'theano' has no attribute 'gof'

# %%
import pymanopt
# Out:
# You can find the C code in this temporary file: /tmp/theano_compilation_error_p4k6tcg8
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/theano/gof/lazylinker_c.py in <module>()
#      80                     version,
# ---> 81                     actual_version, force_compile, _need_reload))
#      82 except ImportError:
#
# ImportError: Version check of the existing lazylinker compiled file. Looking for version 0.211, but found None. Extra debug information: force_compile=False, _need_reload=True
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/theano/gof/lazylinker_c.py in <module>()
#     104                         version,
# --> 105                         actual_version, force_compile, _need_reload))
#     106         except ImportError:
#
# ImportError: Version check of the existing lazylinker compiled file. Looking for version 0.211, but found None. Extra debug information: force_compile=False, _need_reload=True
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/theano/gof/vm.py in <module>()
#     673         raise theano.gof.cmodule.MissingGXX('lazylinker will not be imported if theano.config.cxx is not set.')
# --> 674     from . import lazylinker_c
#     675
#
# ~/.local/lib/python3.6/site-packages/theano/gof/lazylinker_c.py in <module>()
#     139             cmodule.GCC_compiler.compile_str(dirname, code, location=loc,
# --> 140                                              preargs=args)
#     141             # Save version into the __init__.py file.
#
# ~/.local/lib/python3.6/site-packages/theano/gof/cmodule.py in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module, hide_symbols)
#    2395             raise Exception('Compilation failed (return status=%s): %s' %
# -> 2396                             (status, compile_stderr.replace('\n', '. ')))
#    2397         elif config.cmodule.compilation_warning and compile_stderr:
#
# Exception: Compilation failed (return status=1): /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(abstract.o): relocation R_X86_64_32S against symbol `_Py_NotImplementedStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(boolobject.o): relocation R_X86_64_32 against `.data' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(bytearrayobject.o): relocation R_X86_64_32 against symbol `_PyByteArray_empty_string' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(bytesobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(exceptions.o): relocation R_X86_64_32S against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(floatobject.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(funcobject.o): relocation R_X86_64_32S against symbol `PyCode_Type' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(iterobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(listobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(longobject.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(dictobject.o): relocation R_X86_64_32S against `.text' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(memoryobject.o): relocation R_X86_64_32 against `.rodata.str1.8' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(methodobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(moduleobject.o): relocation R_X86_64_32 against `.rodata.str1.8' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(object.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(obmalloc.o): relocation R_X86_64_32S against `.data' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(capsule.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(rangeobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(setobject.o): relocation R_X86_64_32S against `.data' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(sliceobject.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(structseq.o): relocation R_X86_64_32 against `.data' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpy ...
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-f26d8552357b> in <module>()
# ----> 1 import pymanopt
#
# ~/.local/lib/python3.6/site-packages/pymanopt/__init__.py in <module>()
# ----> 1 from .core.problem import Problem
#       2
#       3 __all__ = ["Problem"]
#
# ~/.local/lib/python3.6/site-packages/pymanopt/core/problem.py in <module>()
#       5 from __future__ import print_function
#       6
# ----> 7 from pymanopt.tools.autodiff import (AutogradBackend, TheanoBackend,
#       8                                      TensorflowBackend)
#       9
#
# ~/.local/lib/python3.6/site-packages/pymanopt/tools/autodiff/__init__.py in <module>()
# ----> 1 from ._theano import TheanoBackend
#       2
#       3 from ._autograd import AutogradBackend
#       4
#       5 from ._tensorflow import TensorflowBackend
#
# ~/.local/lib/python3.6/site-packages/pymanopt/tools/autodiff/_theano.py in <module>()
#       6 """
#       7 try:
# ----> 8     import theano
#       9     import theano.tensor as T
#      10     from theano.gradient import disconnected_grad
#
# ~/.local/lib/python3.6/site-packages/theano/__init__.py in <module>()
#     108     object2, utils)
#     109
# --> 110 from theano.compile import (
#     111     SymbolicInput, In,
#     112     SymbolicOutput, Out,
#
# ~/.local/lib/python3.6/site-packages/theano/compile/__init__.py in <module>()
#      10 from theano.compile.function_module import *
#      11
# ---> 12 from theano.compile.mode import *
#      13
#      14 from theano.compile.io import *
#
# ~/.local/lib/python3.6/site-packages/theano/compile/mode.py in <module>()
#       9 import theano
#      10 from theano import gof
# ---> 11 import theano.gof.vm
#      12 from theano import config
#      13 from six import string_types
#
# ~/.local/lib/python3.6/site-packages/theano/gof/vm.py in <module>()
#     681 except ImportError:
#     682     pass
# --> 683 except (OSError, theano.gof.cmodule.MissingGXX) as e:
#     684     # OSError happens when g++ is not installed.  In that case, we
#     685     # already changed the default linker to something else then CVM.
#
# AttributeError: module 'theano' has no attribute 'gof'

# %%
import theano
# Out:
# You can find the C code in this temporary file: /tmp/theano_compilation_error__3fiq_tv
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/theano/gof/lazylinker_c.py in <module>()
#      80                     version,
# ---> 81                     actual_version, force_compile, _need_reload))
#      82 except ImportError:
#
# ImportError: Version check of the existing lazylinker compiled file. Looking for version 0.211, but found None. Extra debug information: force_compile=False, _need_reload=True
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/theano/gof/lazylinker_c.py in <module>()
#     104                         version,
# --> 105                         actual_version, force_compile, _need_reload))
#     106         except ImportError:
#
# ImportError: Version check of the existing lazylinker compiled file. Looking for version 0.211, but found None. Extra debug information: force_compile=False, _need_reload=True
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-1-3397704bd624> in <module>()
# ----> 1 import theano
#
# ~/.local/lib/python3.6/site-packages/theano/__init__.py in <module>()
#     108     object2, utils)
#     109
# --> 110 from theano.compile import (
#     111     SymbolicInput, In,
#     112     SymbolicOutput, Out,
#
# ~/.local/lib/python3.6/site-packages/theano/compile/__init__.py in <module>()
#      10 from theano.compile.function_module import *
#      11
# ---> 12 from theano.compile.mode import *
#      13
#      14 from theano.compile.io import *
#
# ~/.local/lib/python3.6/site-packages/theano/compile/mode.py in <module>()
#       9 import theano
#      10 from theano import gof
# ---> 11 import theano.gof.vm
#      12 from theano import config
#      13 from six import string_types
#
# ~/.local/lib/python3.6/site-packages/theano/gof/vm.py in <module>()
#     672     if not theano.config.cxx:
#     673         raise theano.gof.cmodule.MissingGXX('lazylinker will not be imported if theano.config.cxx is not set.')
# --> 674     from . import lazylinker_c
#     675
#     676     class CVM(lazylinker_c.CLazyLinker, VM):
#
# ~/.local/lib/python3.6/site-packages/theano/gof/lazylinker_c.py in <module>()
#     138             args = cmodule.GCC_compiler.compile_args()
#     139             cmodule.GCC_compiler.compile_str(dirname, code, location=loc,
# --> 140                                              preargs=args)
#     141             # Save version into the __init__.py file.
#     142             init_py = os.path.join(loc, '__init__.py')
#
# ~/.local/lib/python3.6/site-packages/theano/gof/cmodule.py in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module, hide_symbols)
#    2394             # difficult to read.
#    2395             raise Exception('Compilation failed (return status=%s): %s' %
# -> 2396                             (status, compile_stderr.replace('\n', '. ')))
#    2397         elif config.cmodule.compilation_warning and compile_stderr:
#    2398             # Print errors just below the command line.
#
# Exception: Compilation failed (return status=1): /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(abstract.o): relocation R_X86_64_32S against symbol `_Py_NotImplementedStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(boolobject.o): relocation R_X86_64_32 against `.data' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(bytearrayobject.o): relocation R_X86_64_32 against symbol `_PyByteArray_empty_string' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(bytesobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(exceptions.o): relocation R_X86_64_32S against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(floatobject.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(funcobject.o): relocation R_X86_64_32S against symbol `PyCode_Type' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(iterobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(listobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(longobject.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(dictobject.o): relocation R_X86_64_32S against `.text' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(memoryobject.o): relocation R_X86_64_32 against `.rodata.str1.8' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(methodobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(moduleobject.o): relocation R_X86_64_32 against `.rodata.str1.8' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(object.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(obmalloc.o): relocation R_X86_64_32S against `.data' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(capsule.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(rangeobject.o): relocation R_X86_64_32 against symbol `_Py_NoneStruct' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(setobject.o): relocation R_X86_64_32S against `.data' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(sliceobject.o): relocation R_X86_64_32 against `.rodata.str1.1' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpython3.6m.a(structseq.o): relocation R_X86_64_32 against `.data' can not be used when making a shared object; recompile with -fPIC. /usr/bin/ld: /auto/pkg/python-3.6/lib/libpy ...
