# %% [markdown]
# ### Unconstrained sampling with Dirichlet-Laplace shrunkage prior:

# %%
import matplotlib.pyplot as plt, numpy as np, numpy.random as npr, pystan as ps, matplotlib.pyplot as plt
from tqdm import trange
import scipy
# %matplotlib inline
from time import time
from pylab import plot, show, legend

# %% [markdown]
# #### Compile Stan model:

# %%
sm = ps.StanModel(file="brain_DL.stan")
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_d6b2d0b798f12e3033751722baf72ffd NOW.

# %% [markdown]
# #### Load data from file and prepare stan data list:

# %%
from numpy import loadtxt

X = np.zeros((42,68,68))
for i in range(42) :
    name = "/home/postdoc/dsen/Desktop/projeted_posterior/brain_data/data_column"+str(i+1)
    X[i] = loadtxt(name, comments="#", delimiter=" ", unpack=False)
X = X.astype(int)

# N = 21 
# m = np.shape(X)[1]
# p = 10
# a = 1/m
# data = dict(N=N, R=m, d=p, X=X[:N], alpha=1/m, lmbda=0.5)

N = 10 
m = 6
p = 3
a = 1./m
data = dict(N=N, p=p, m=m, a=a, X=X[:N,:m,:m])

print(np.mean(X[:N,:m,:m]))
# Out:
# 0.3888888888888889

# %% [raw]
# N = 21
# m = 10
# X = npr.binomial(n=1,p=0.3,size=(N,m,m))
# p = 5
# a = 1/m
# data = dict(N=N, p=p, m=m, a=a, X=X[:N]);

# %% [markdown]
# #### Sample using stan:

# %%
control = dict(max_treedepth=10)
start = time()
fit = sm.sampling(data=data, thin=1, n_jobs=4, chains=4, iter=1_000, init="random")
print(round((time()-start)/60,2), "minutes to run")
print(fit)
trace = fit.extract()
# Out:
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:2000 of 2000 iterations saturated the maximum tree depth of 10 (100 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# 6.11 minutes to run
# Inference for Stan model: anon_model_d6b2d0b798f12e3033751722baf72ffd.
# 4 chains, each with iter=1000; warmup=500; thin=1;
# post-warmup draws per chain=500, total post-warmup draws=2000.
#
#                mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# Z[1,1]         -4.0    2.12   3.24  -7.93  -6.44  -5.11  -0.64   1.64      2   5.17
# Z[2,1]        -1.48     0.3   0.53  -2.28  -1.93   -1.5  -1.28  -0.24      3   2.01
# Z[3,1]         2.24    2.54   3.63  -3.32  -0.92   2.02   5.54   7.78      2    9.1
# Z[4,1]         0.89    0.29   0.48   0.14   0.58    0.7   1.25   1.98      3    2.1
# Z[5,1]         0.95    0.69   1.15  -1.03  -0.09   0.89   1.78   3.04      3   2.36
# Z[6,1]        -2.41     0.5   0.76  -3.62  -3.18  -2.27  -1.73  -1.26      2   4.23
# Z[1,2]        -2.25    0.59   0.98  -3.79  -3.33  -2.08  -1.48  -0.75      3   2.42
# Z[2,2]        -5.56    1.01    1.8  -7.95  -7.22  -5.92  -3.52  -2.86      3   3.36
# Z[3,2]          3.5    0.72   1.37   1.93   2.43   2.86   4.46   6.47      4   1.86
# Z[4,2]         4.74    0.87   1.33   2.69   3.75   4.26   6.24    7.0      2   3.17
# Z[5,2]        -4.28    0.42   0.65  -5.46  -4.77   -4.2  -3.69  -3.22      2   3.07
# Z[6,2]         -3.3    0.52    0.9  -4.84  -4.05  -3.21  -2.76  -1.41      3   2.11
# Z[1,3]         3.32     0.4   0.97   1.93   2.34   3.45   3.94   5.36      6    2.0
# u[2,2]        -0.66    0.46   0.74  -1.85  -1.45  -0.08  -0.02   0.03      3   2.52
# u[3,2]        -0.01  7.4e-3   0.02  -0.05  -0.03-8.8e-3 1.2e-3   0.03      7    1.5
# u[4,2]         0.79    0.85   1.32  -0.03-2.6e-3   0.08   0.68   4.14      2   4.85
# u[5,2]        -1.45    2.09   3.14  -9.54  -1.94 2.7e-3   0.41   0.83      2   5.56
# u[6,2]        -0.06    0.03   0.06  -0.19   -0.1  -0.02-2.5e-4 9.9e-4      3   1.99
# u[1,3]        -0.95    1.52   2.15  -4.81  -2.54  -0.09   0.45    1.5      2  15.28
# u[2,3]        -0.34    0.41   0.59  -1.63   -0.5-1.7e-3 2.4e-4 7.0e-3      2   8.81
# u[3,3]         6.33    7.75  10.98  -0.06-7.7e-3-2.9e-4  12.38  27.05      2  26.98
# u[4,3]        -0.06    0.03   0.09  -0.38   -0.1  -0.03 4.3e-6   0.05      7   1.39
# u[5,3]         0.28    0.33   0.47  -0.13-2.2e-3 6.2e-3   0.71   1.18      2   8.07
# u[6,3]         0.23    0.29   0.41  -0.07-3.4e-4 8.3e-4   0.52   1.07      2  12.18
# Lambda[1,1]    0.18    0.11   0.24  -0.35 9.7e-3   0.21   0.35   0.59      5   1.76
# Lambda[2,1]    0.11    0.19   0.35  -0.48  -0.19   0.07   0.47   0.68      3   1.94
# Lambda[3,1]    0.16     0.1   0.32  -0.84   0.09    0.2   0.31   0.64     10   1.37
# Lambda[4,1]  5.2e-3    0.04   0.22  -0.51  -0.12 6.0e-3   0.14   0.51     25   1.16
# Lambda[5,1]   -0.07    0.18   0.34  -0.75  -0.32  -0.03   0.26    0.4      4   1.81
# Lambda[6,1]   -0.05    0.07   0.29  -0.94  -0.21   0.04   0.13   0.37     18   1.28
# Lambda[7,1]   -0.09    0.11   0.34  -0.71  -0.34   -0.1   0.14   0.67     10   1.35
# Lambda[8,1]   -0.09    0.08   0.29  -0.81  -0.18  -0.11   0.06   0.47     13   1.45
# Lambda[9,1]   -0.11    0.12   0.25  -0.65  -0.24  -0.12   0.09   0.28      5    1.5
# Lambda[10,1]   0.06    0.14   0.28   -0.5  -0.19   0.14   0.29   0.46      4   2.42
# Lambda[1,2]   -0.36    0.43   0.73  -1.87  -0.71  -0.45   0.28   0.87      3   2.66
# Lambda[2,2]    0.04    0.08   0.32  -0.76  -0.03   0.04   0.19   0.72     15   1.13
# Lambda[3,2]   -0.31    0.26   0.43   -1.1  -0.59  -0.26  -0.12   0.61      3   2.67
# Lambda[4,2]   -0.11    0.42   0.66   -1.6  -0.52   0.03   0.56   0.66      2   2.71
# Lambda[5,2]   -0.45    0.43   0.68  -2.03  -0.79   -0.2  -0.02   0.45      2   2.56
# Lambda[6,2]   -0.44    0.31   0.64  -2.33  -0.54  -0.41  -0.21   0.56      4   1.98
# Lambda[7,2]   -0.08    0.73   1.06   -1.5  -0.92  -0.29   0.91   1.74      2   7.62
# Lambda[8,2]   -0.33    0.24   0.47  -1.53  -0.43  -0.27-2.1e-3   0.29      4   1.77
# Lambda[9,2]   -0.01    0.29   0.44   -0.7  -0.36  -0.09   0.17   0.99      2   2.92
# Lambda[10,2]  -0.23    0.43   0.75  -2.15  -0.41  -0.27   0.46   0.56      3   1.94
# Lambda[1,3]    0.22    0.18   0.43  -0.57  -0.15   0.24   0.58   0.99      6   1.42
# Lambda[2,3]     0.1    0.48   0.76  -0.76  -0.56  -0.13   0.55    1.8      3   2.61
# Lambda[3,3]   -0.73    0.93   1.33  -3.36  -1.47  -0.43    0.2   0.81      2  12.89
# Lambda[4,3]    0.75    1.02   1.46  -0.37  -0.29  -0.08   2.14   3.49      2   8.42
# Lambda[5,3]   -0.24    0.49   0.85  -1.44  -1.34   0.02   0.43   1.02      3   2.39
# Lambda[6,3]    0.04    0.37   0.74  -0.78  -0.55  -0.12   0.19    2.1      4   3.98
# Lambda[7,3]    0.56    0.86   1.26  -0.55  -0.45-5.6e-3   1.03   3.33      2   4.69
# Lambda[8,3]   -0.16    0.13   0.63  -1.66  -0.49  -0.18   0.18   1.05     24    1.1
# Lambda[9,3]   -0.32     0.4   0.66  -1.05  -0.88  -0.39  -0.16   1.43      3   2.65
# Lambda[10,3]   -0.4    0.35   0.91  -2.79  -0.41  -0.05  -0.04   0.68      7   1.53
# sigma_Z2       3.32    0.32   0.49   2.78   2.98   3.06    3.7   4.32      2   3.59
# sigma2[1]      0.36    0.07   0.15   0.18   0.27   0.36   0.39   0.79      5   1.46
# sigma2[2]      0.64    0.23   0.36   0.36    0.4   0.51   0.64   1.55      2   3.64
# sigma2[3]      0.78    0.37   0.54   0.25   0.32   0.71   0.94    2.0      2   4.45
# tau[1]         1.16     0.7   1.04   0.04   0.35   0.72   2.31   3.11      2    4.7
# tau[2]         3.35    2.17   3.31   0.16   0.24   1.94   6.23  10.36      2   3.08
# tau[3]         3.88    2.52   3.58   0.17   0.89   2.89   7.63   9.94      2  12.22
# phi[1,1]       0.49    0.08   0.21   0.02   0.41   0.56   0.63   0.75      7   1.99
# phi[2,1]       0.09    0.11   0.16 2.4e-5 3.4e-4 3.4e-3   0.18    0.4      2  19.04
# phi[3,1]       0.33     0.2    0.3   0.01    0.1   0.18   0.67   0.91      2    5.4
# phi[1,2]       0.13     0.1   0.14 1.7e-5 3.2e-4   0.08   0.23   0.42      2   7.31
# phi[2,2]       0.27    0.12   0.19 7.6e-3   0.07   0.33   0.43   0.56      3   2.44
# phi[3,2]       0.17    0.19   0.29 1.1e-4 8.7e-4 9.7e-3    0.2   0.87      2   5.22
# phi[1,3]       0.13    0.09   0.15 1.8e-4 3.8e-3   0.07   0.22   0.49      3   2.16
# phi[2,3]       0.12     0.1   0.16 5.7e-4 1.5e-3 7.2e-3    0.3    0.4      2   2.67
# phi[3,3]       0.24    0.19   0.31 3.5e-4 2.5e-3   0.02   0.63   0.76      2    6.6
# phi[1,4]       0.06    0.05    0.1 3.7e-7 1.6e-4   0.01   0.06   0.38      5   1.88
# phi[2,4]       0.27    0.21   0.32 9.3e-4 3.7e-3   0.06   0.52    0.9      2   3.27
# phi[3,4]       0.11    0.13   0.19 1.2e-5 1.6e-3 4.4e-3   0.05   0.58      2    5.0
# phi[1,5]       0.11    0.12    0.2 9.7e-5 6.6e-4 5.2e-3   0.13   0.67      3   2.17
# phi[2,5]       0.21    0.14   0.22 1.1e-4   0.03   0.19   0.31    0.7      2   3.93
# phi[3,5]       0.07    0.05   0.08 6.4e-3   0.01   0.06    0.1   0.29      3   4.15
# phi[1,6]       0.09    0.08   0.14 3.5e-6 1.4e-3   0.04   0.08   0.52      3   2.07
# phi[2,6]       0.04    0.03   0.04 1.3e-5 4.0e-3   0.02   0.09   0.12      3   2.18
# phi[3,6]       0.07    0.05   0.09 1.6e-5 1.3e-3   0.03   0.08   0.33      3   3.46
# lp__         -128.7   15.11  21.92 -160.6 -148.3 -137.6 -106.2 -99.76      2   4.91
#
# Samples were drawn using NUTS at Mon Mar  2 12:34:29 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %% [markdown]
# #### Plot log-likelihoods of posterior samples:

# %%
trace['Lambda']
# Out:
# array([[[-0.25593187,  0.87195394,  0.53051999],
#         [-0.43665009, -0.15530734,  0.5298622 ],
#         [ 0.10196867,  0.17744494,  0.83261177],
#         ...,
#         [-0.81617995, -0.37601968,  0.77948455],
#         [-0.7483504 ,  0.19373887, -0.30452037],
#         [ 0.33529537, -0.59704113,  0.21123491]],
#
#        [[-0.01042464, -0.6026819 , -0.10250877],
#         [-0.36512441, -0.61604205,  0.00308421],
#         [-0.14790751,  0.40119189,  0.68578977],
#         ...,
#         [ 0.06815488, -0.5651923 ,  0.11778289],
#         [-0.03681173,  0.47817095, -0.87186737],
#         [ 0.38433802,  0.12872665,  0.6067006 ]],
#
#        [[ 0.1816224 ,  0.98170926,  0.36946937],
#         [-0.28839174,  0.10909809,  0.40282834],
#         [ 0.3448747 ,  0.26320022,  0.6777117 ],
#         ...,
#         [ 0.35866088, -0.31019443, -0.63224487],
#         [-0.02167725,  0.28749759, -0.91088689],
#         [ 0.38226855,  0.59705435,  0.39720058]],
#
#        ...,
#
#        [[ 0.49579664, -1.50148812,  0.24177758],
#         [ 0.11859688, -0.06308775,  1.01111745],
#         [ 0.2100503 , -0.65856867, -2.67666932],
#         ...,
#         [ 0.3336389 , -1.20167752,  0.67593021],
#         [ 0.09044908, -0.34958582,  0.68209177],
#         [ 0.17969887, -2.37983868, -2.75585598]],
#
#        [[ 0.14175876, -1.40796667, -0.5381853 ],
#         [-0.1736051 , -0.01395092,  1.88166848],
#         [ 0.32200989, -0.85560286, -2.67622009],
#         ...,
#         [ 0.07969518, -1.35910922, -2.50917502],
#         [ 0.24262596, -0.18303227,  1.09343153],
#         [ 0.16942821, -0.96907616, -1.61480855]],
#
#        [[ 0.02780825, -1.01190673, -0.57091829],
#         [ 0.06647493, -0.04850611,  1.48397099],
#         [ 0.33299177, -0.8003828 , -3.07663667],
#         ...,
#         [-0.07657237, -0.28995403, -2.1684039 ],
#         [-0.0749787 , -0.44526217,  0.87189113],
#         [ 0.15528173, -1.40557498, -0.63429126]]])
