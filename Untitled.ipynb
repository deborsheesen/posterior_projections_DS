# %%
import rpy2.robjects as robjects
robjects.r['load']("kki42.rda")
# Out:
# array(['tensorA'], dtype='<U7')

# %%
import numpy as np, csv

# %%
data = np.load("KKI.edges")
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /auto/pkg/python-3.6/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     427             try:
# --> 428                 return pickle.load(fid, **pickle_kwargs)
#     429             except Exception:
#
# UnpicklingError: could not find MARK
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-30-918a4f46eba3> in <module>()
# ----> 1 data = np.load("KKI.edges")
#
# /auto/pkg/python-3.6/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     429             except Exception:
#     430                 raise IOError(
# ...

# %%
f = open("KKI.edges", 'r')
x = f.readlines()
f.close()

# %%
x
# Out:
# ['1,2\n',
#  '2,1\n',
#  '2,3\n',
#  '3,2\n',
#  '2,4\n',
#  '4,2\n',
#  '3,4\n',
#  '4,3\n',
#  '3,5\n',
#  '5,3\n',
#  '3,6\n',
#  '6,3\n',
#  '3,7\n',
#  '7,3\n',
#  '3,8\n',
#  '8,3\n',
#  '3,9\n',
#  '9,3\n',
#  '3,10\n',
#  '10,3\n',
#  '4,10\n',
#  '10,4\n',
#  '5,8\n',
#  '8,5\n',
#  '5,9\n',
#  '9,5\n',
#  '5,11\n',
#  '11,5\n',
#  '5,12\n',
#  '12,5\n',
#  '5,13\n',
#  '13,5\n',
#  '5,14\n',
#  '14,5\n',
#  '5,15\n',
#  '15,5\n',
#  '5,16\n',
#  '16,5\n',
#  '5,17\n',
#  '17,5\n',
#  '5,18\n',
#  '18,5\n',
#  '5,19\n',
#  '19,5\n',
#  '6,9\n',
#  '9,6\n',
#  '6,10\n',
#  '10,6\n',
#  '6,13\n',
#  '13,6\n',
#  '6,15\n',
#  '15,6\n',
#  '6,20\n',
#  '20,6\n',
#  '7,10\n',
#  '10,7\n',
#  '7,15\n',
#  '15,7\n',
#  '7,21\n',
#  '21,7\n',
#  '8,12\n',
#  '12,8\n',
#  '8,19\n',
#  '19,8\n',
#  '9,11\n',
#  '11,9\n',
#  '9,15\n',
#  '15,9\n',
#  '9,16\n',
#  '16,9\n',
#  '9,18\n',
#  '18,9\n',
#  '9,19\n',
#  '19,9\n',
#  '9,22\n',
#  '22,9\n',
#  '11,16\n',
#  '16,11\n',
# ...
